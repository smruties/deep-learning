# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_words = len(int_words)
freqs = {word: count/total_words for word, count in word_counts.items()}
p_drop = {word: 1-np.sqrt(threshold/freqs[word]) for word in word_counts}


train_words = [word for word in int_words if p_drop[word] < random.random()]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R)>0 else 0;
    end = idx + R
    target_words = set(words[start:idx] + words[idx+1:end+1])
    
    return target_words

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200# Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform([n_vocab,n_embedding],-1.0,1.0)) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1)) # create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab)) # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b,
                                     labels, embed,
                                     n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-4e2db0809788> in <module>()
#       1 # Number of negative labels to sample
#       2 n_sampled = 100
# ----> 3 with train_graph.as_default():
#       4     softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1)) # create softmax weight matrix here
#       5     softmax_b = tf.Variable(tf.zeros(n_vocab)) # create softmax biases here
#
# NameError: name 'train_graph' is not defined

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6345 0.2675 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.5954 0.3107 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5296 0.2981 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5741 0.3273 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.4956 0.2912 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5409 0.3314 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5660 0.3081 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5645 0.3235 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4927 0.3592 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4119 0.3288 sec/batch
# Nearest to after: ivana, refuelling, imad, grew, garry, period, luzon, signification,
# Nearest to american: philosophies, bestseller, jumped, slovenia, galatian, playfair, bidding, monomers,
# Nearest to these: conquering, depriving, quimby, spear, offending, reassembly, sprung, ashkenazim,
# Nearest to who: urinary, portugal, particulate, gottorp, moldings, printings, cvn, echelons,
# Nearest to the: architect, two, number, date, leniency, bewildered, hdi, marsupial,
# Nearest to six: vernal, suzhou, human, tamper, lepers, basten, richardson, palatine,
# Nearest to years: gregor, schell, president, chem, awami, ats, respublika, antioquia,
# Nearest to united: formalized, khyber, rup, appalachia, scientifiques, fired, internship, wildcard,
# Nearest to gold: casas, vauquelin, salutis, infancy, deteriorated, woodworking, stomach, glastonbury,
# Nearest to heavy: magnesians, cana, euphemistic, unicorns, parlay, workload, republik, abstractly,
# Nearest to pressure: absolutely, jensen, reexports, safeguard, sous, cee, langue, schlenkerla,
# Nearest to existence: amphibious, defenses, pesach, antofagasta, dissociate, curled, commit, clueless,
# Nearest to brother: takla, perfected, nubians, equaled, isl, perestroika, ibaraki, heroics,
# Nearest to additional: wertham, girondins, tld, pms, webelements, legged, rising, runic,
# Nearest to applied: vesper, dopamine, yelled, typhoons, powell, fork, marcello, intruding,
# Nearest to dr: toaster, spinrad, smeaton, circulatory, barkley, episode, van, blames,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4457 0.2824 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3881 0.2848 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3398 0.2835 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2185 0.2880 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1647 0.2849 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1331 0.2864 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0845 0.2862 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0535 0.2842 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.9951 0.2919 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9716 0.2999 sec/batch
# Nearest to after: period, grew, decades, ivana, refuelling, leaders, vacuum, seaman,
# Nearest to american: philosophies, bestseller, slovenia, father, lasted, during, nicholas, hoped,
# Nearest to these: conquering, depriving, quimby, therefore, degrees, complete, offending, sprung,
# Nearest to who: circumstances, portugal, did, reception, gottorp, urinary, echelons, derivatives,
# Nearest to the: date, architect, not, number, bewildered, chicken, ones, marsupial,
# Nearest to six: vernal, human, sides, pianist, suzhou, richardson, tamper, consecutive,
# Nearest to years: president, of, diverse, gregor, land, main, generally, accept,
# Nearest to united: formalized, throughout, fired, epidemic, disrupted, khyber, wicca, paradoxer,
# Nearest to gold: casas, infancy, vauquelin, general, deteriorated, kong, stomach, glastonbury,
# Nearest to heavy: cana, abstractly, survive, college, magnesians, picked, occupied, gently,
# Nearest to pressure: absolutely, safeguard, langue, reexports, therefore, lebanese, already, dwindling,
# Nearest to existence: amphibious, commit, gives, defenses, improved, evangelical, there, dissociate,
# Nearest to brother: takla, perfected, nubians, equaled, isl, byron, obligation, heroics,
# Nearest to additional: rising, tld, complete, runic, begun, williams, uncommon, wertham,
# Nearest to applied: vesper, gathered, dopamine, powell, reverting, goss, yelled, marcello,
# Nearest to dr: understanding, toaster, spinrad, van, circulatory, episode, smeaton, indicated,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9155 0.2958 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.8926 0.2901 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8573 0.2846 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8549 0.3095 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8124 0.2902 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8233 0.2942 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8142 0.2928 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7837 0.2918 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7962 0.2957 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7812 0.2932 sec/batch
# Nearest to after: grew, period, francis, refuelling, decades, garry, ivana, imad,
# Nearest to american: bestseller, philosophies, father, lasted, philadelphia, playfair, slovenia, nicholas,
# Nearest to these: conquering, depriving, offending, degrees, therefore, quimby, sprung, spear,
# Nearest to who: particulate, portugal, did, reception, circumstances, echelons, captaincy, genuine,
# Nearest to the: date, architect, not, marsupial, love, hdi, bewildered, ones,
# Nearest to six: vernal, richardson, palatine, pianist, suzhou, lepers, austrian, wenzel,
# Nearest to years: gregor, diverse, president, of, accelerates, accept, hubble, request,
# Nearest to united: formalized, throughout, khyber, oddities, undesirable, epidemic, nationality, merv,
# Nearest to gold: deteriorated, stomach, casas, kong, vauquelin, glastonbury, woodworking, symbolizing,
# Nearest to heavy: abstractly, survive, euphemistic, occupied, workload, picked, jefferson, cana,
# Nearest to pressure: absolutely, safeguard, reexports, langue, lebanese, folding, expounds, elijah,
# Nearest to existence: amphibious, defenses, commit, goddard, evangelical, axioms, dissociate, gives,
# Nearest to brother: perfected, takla, nubians, isl, byron, penalty, heroics, equaled,
# Nearest to additional: tld, rising, runic, islanders, wertham, legged, uncommon, begun,
# Nearest to applied: vesper, gathered, powell, fork, reverting, typhoons, yelled, scientists,
# Nearest to dr: toaster, understanding, spinrad, smeaton, circulatory, van, barkley, members,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7537 0.2995 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7415 0.2959 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7159 0.2972 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7231 0.2918 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7421 0.3019 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7171 0.3026 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.6986 0.2993 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7268 0.2962 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7238 0.2946 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6480 0.2936 sec/batch
# Nearest to after: francis, grew, period, leaders, imad, garry, ivana, forced,
# Nearest to american: bestseller, nine, father, philadelphia, lasted, renowned, playfair, philosophies,
# Nearest to these: conquering, offending, depriving, therefore, degrees, sprung, quimby, reassembly,
# Nearest to who: particulate, captaincy, did, portugal, reception, circumstances, printings, tat,
# Nearest to the: date, marsupial, ambitious, decree, love, not, rhetorical, ankle,
# Nearest to six: vernal, one, austrian, eight, pianist, zero, palatine, richardson,
# Nearest to years: gregor, president, diverse, of, seven, expectancy, approximates, accelerates,
# Nearest to united: formalized, khyber, throughout, oddities, nationality, merv, undesirable, combatant,
# Nearest to gold: glastonbury, deteriorated, stomach, vauquelin, casas, kong, woodworking, symbolizing,
# Nearest to heavy: abstractly, jefferson, euphemistic, workload, gently, parlay, cana, occupied,
# Nearest to pressure: absolutely, safeguard, folding, langue, sous, reexports, expounds, silvery,
# Nearest to existence: amphibious, defenses, pesach, commit, dissociate, goddard, evangelical, communicates,
# Nearest to brother: isl, nubians, takla, perfected, heroics, byron, equaled, penalty,
# Nearest to additional: tld, legged, runic, rising, wertham, islanders, girondins, amerindians,
# Nearest to applied: vesper, fork, yelled, appreciate, reverting, powell, scientists, oppression,
# Nearest to dr: toaster, spinrad, smeaton, earl, circulatory, van, members, understanding,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6670 0.2998 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6937 0.2911 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6129 0.2973 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6161 0.2971 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6518 0.2956 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6158 0.2938 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6080 0.2225 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5286 0.2958 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5257 0.2940 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5088 0.2958 sec/batch
# Nearest to after: francis, ivana, grew, leaders, period, imad, garry, forced,
# Nearest to american: nine, singer, bestseller, d, philadelphia, father, musician, nicholas,
# Nearest to these: conquering, offending, therefore, depriving, sprung, degrees, arbitrate, munitions,
# Nearest to who: did, particulate, captaincy, reception, portugal, circumstances, gottorp, printings,
# Nearest to the: ambitious, date, marsupial, decree, unaffected, love, allomorphy, ankle,
# Nearest to six: one, eight, pianist, austrian, chemist, vernal, zero, palatine,
# Nearest to years: gregor, president, expectancy, diverse, of, blackmail, ats, awami,
# Nearest to united: formalized, khyber, throughout, nationality, oddities, merv, wales, internship,
# Nearest to gold: glastonbury, casas, deteriorated, vauquelin, stomach, dmz, salutis, kong,
# Nearest to heavy: abstractly, parlay, gently, bite, jefferson, euphemistic, picked, workload,
# Nearest to pressure: absolutely, folding, sous, safeguard, reexports, expounds, silvery, undp,
# Nearest to existence: commit, defenses, amphibious, dissociate, axioms, pesach, consensus, goddard,
# Nearest to brother: isl, byron, nubians, heroics, takla, ibaraki, affirmative, perestroika,
# Nearest to additional: tld, legged, wertham, runic, rising, girondins, islanders, amerindians,
# Nearest to applied: vesper, appreciate, meditations, scientists, fork, dragster, tempus, gouda,
# Nearest to dr: toaster, spinrad, earl, smeaton, van, members, circulatory, instructor,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4926 0.3004 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4827 0.2935 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4763 0.2949 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5344 0.2988 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.5050 0.2959 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4817 0.2988 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4788 0.3002 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4242 0.3036 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4660 0.2992 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4504 0.2997 sec/batch
# Nearest to after: imad, ivana, grew, francis, period, leaders, forced, signification,
# Nearest to american: bestseller, nicholas, philadelphia, riyadh, lasted, mel, jumped, playfair,
# Nearest to these: conquering, therefore, depriving, offending, degrees, arbitrate, munitions, scale,
# Nearest to who: did, particulate, rebellious, circumstances, printings, reception, captaincy, resurrection,
# Nearest to the: unaffected, resulted, headland, banach, ambitious, date, underlined, geographic,
# Nearest to six: vernal, one, zero, lepers, austrian, eight, wenzel, shoku,
# Nearest to years: expectancy, gregor, hiv, president, fertility, diverse, infant, migrant,
# Nearest to united: formalized, oddities, throughout, cuba, nationality, khyber, appalachia, merv,
# Nearest to gold: glastonbury, vauquelin, dmz, telegraphic, casas, kerenyi, conspire, salutis,
# Nearest to heavy: parlay, abstractly, scaring, picked, gently, bite, hahnemann, cana,
# Nearest to pressure: absolutely, melting, folding, silvery, sous, undp, safeguard, schlenkerla,
# Nearest to existence: commit, axioms, iq, dissociate, defenses, consensus, pesach, judge,
# Nearest to brother: isl, takla, nubians, byron, heroics, ibaraki, bandwagon, perestroika,
# Nearest to additional: wertham, legged, tld, runic, rising, girondins, glycogen, clover,
# Nearest to applied: vesper, scientists, appreciate, meditations, gouda, dragster, downloaded, plank,
# Nearest to dr: toaster, earl, spinrad, smeaton, van, willem, elish, goldwater,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4374 0.3052 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4371 0.3024 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4235 0.2980 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3919 0.2981 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4002 0.2976 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4371 0.3000 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3703 0.2965 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3942 0.2980 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4178 0.2986 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3911 0.2994 sec/batch
# Nearest to after: ivana, francis, imad, garry, grew, seaman, period, stripper,
# Nearest to american: bestseller, nicholas, riyadh, lasted, mel, jumped, singer, philadelphia,
# Nearest to these: conquering, therefore, depriving, offending, sacramental, constitutionalism, arbitrate, gilead,
# Nearest to who: did, particulate, tat, rebellious, captaincy, printings, cvn, genuine,
# Nearest to the: underlined, marsupial, unaffected, ethnographers, headland, banach, resulted, windsurfing,
# Nearest to six: one, eight, zero, shoku, lepers, austrian, wenzel, vernal,
# Nearest to years: expectancy, gregor, hiv, fertility, diverse, infant, president, migrant,
# Nearest to united: formalized, oddities, cuba, khyber, nationality, appalachia, throughout, states,
# Nearest to gold: glastonbury, vauquelin, dmz, kong, telegraphic, hegemonic, kerenyi, cliques,
# Nearest to heavy: parlay, scaring, bite, gently, abstractly, picked, okavango, saline,
# Nearest to pressure: absolutely, melting, folding, higher, silvery, humid, undp, emission,
# Nearest to existence: axioms, commit, consensus, pesach, judge, defenses, dissociate, iq,
# Nearest to brother: isl, byron, takla, ibaraki, nubians, heroics, wife, blockaded,
# Nearest to additional: wertham, legged, glycogen, runic, tld, girondins, pms, fante,
# Nearest to applied: scientists, appreciate, vesper, dragster, gouda, meditations, downloaded, hippos,
# Nearest to dr: toaster, smeaton, spinrad, earl, episode, van, goldwater, harmondsworth,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3822 0.3003 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3799 0.3000 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3872 0.3007 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3446 0.2985 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.4326 0.2970 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3630 0.2977 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3929 0.2949 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3656 0.2984 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3206 0.2980 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3451 0.2968 sec/batch
# Nearest to after: imad, forced, francis, ivana, period, was, seaman, grew,
# Nearest to american: bestseller, jumped, riyadh, nicholas, wade, playfair, flo, simmons,
# Nearest to these: conquering, therefore, depriving, arbitrate, offending, separations, gilead, sacramental,
# Nearest to who: did, genuine, rebellious, friesian, cvn, tat, resurrection, echelons,
# Nearest to the: unaffected, akayev, populace, soichiro, resulted, banach, windsurfing, underlined,
# Nearest to six: zero, one, eight, three, vernal, shoku, wenzel, lepers,
# Nearest to years: expectancy, fertility, hiv, gregor, infant, antioquia, mortality, migrant,
# Nearest to united: oddities, formalized, cuba, states, khyber, throughout, nationality, appalachia,
# Nearest to gold: glastonbury, kong, grown, dmz, hegemonic, telegraphic, vauquelin, zone,
# Nearest to heavy: parlay, bite, picked, gently, abstractly, okavango, saline, scaring,
# Nearest to pressure: absolutely, melting, silvery, undp, folding, humid, sous, schlenkerla,
# Nearest to existence: axioms, judge, commit, pesach, manasseh, consensus, evangelical, defenses,
# Nearest to brother: byron, isl, wife, takla, heroics, peshawar, ibaraki, nubians,
# Nearest to additional: tld, wertham, legged, girondins, glycogen, fante, inventories, rising,
# Nearest to applied: scientists, vesper, gouda, meditations, appreciate, downloaded, dragster, bream,
# Nearest to dr: toaster, spinrad, smeaton, earl, van, harmondsworth, episode, goldwater,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3326 0.3032 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.3089 0.3002 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3943 0.2973 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3775 0.2985 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3827 0.2953 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.3006 0.2969 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3141 0.2920 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3569 0.2959 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2457 0.2991 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.3078 0.2991 sec/batch
# Nearest to after: imad, seaman, was, ivana, francis, stripper, luzon, grew,
# Nearest to american: bestseller, jumped, nicholas, musician, singer, emil, flo, pianist,
# Nearest to these: conquering, therefore, arbitrate, depriving, separations, sacramental, preventing, munitions,
# Nearest to who: genuine, rebellious, did, friesian, echelons, particulate, rulership, resurrection,
# Nearest to the: geographic, soichiro, underlined, resulted, unaffected, windsurfing, fatwas, doubled,
# Nearest to six: one, zero, eight, three, wenzel, shoku, vernal, four,
# Nearest to years: expectancy, fertility, infant, migrant, hiv, mortality, birth, female,
# Nearest to united: cuba, formalized, oddities, states, appalachia, khyber, internship, throughout,
# Nearest to gold: glastonbury, dmz, hegemonic, grown, kong, conspire, remarking, telegraphic,
# Nearest to heavy: parlay, bite, picked, okavango, scaring, saline, gently, hmas,
# Nearest to pressure: absolutely, silvery, melting, undp, humid, sous, schlenkerla, folding,
# Nearest to existence: axioms, commit, prove, logia, pesach, judge, manasseh, defenses,
# Nearest to brother: byron, isl, ibaraki, blockaded, takla, nubians, heroics, wife,
# Nearest to additional: wertham, tld, glycogen, girondins, inventories, legged, fante, chymotrypsin,
# Nearest to applied: scientists, vesper, appreciate, gouda, meditations, downloaded, dragster, hippos,
# Nearest to dr: toaster, spinrad, smeaton, earl, van, harmondsworth, episode, goldwater,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.2997 0.3015 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.3152 0.3054 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3317 0.1412 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2688 0.3026 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2146 0.2954 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2437 0.2958 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2419 0.2932 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2208 0.2944 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2335 33.2089 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.2098 0.3931 sec/batch
# Nearest to after: ivana, was, imad, seaman, cornucopia, grew, francis, stripper,
# Nearest to american: bestseller, jumped, emil, riyadh, musician, flo, wade, max,
# Nearest to these: conquering, arbitrate, therefore, depriving, separations, sacramental, of, reassembly,
# Nearest to who: rebellious, genuine, did, friesian, echelons, flavius, quintessentially, her,
# Nearest to the: soichiro, geographic, an, underlined, ethnographers, sig, fatwas, windsurfing,
# Nearest to six: one, zero, eight, three, wenzel, vernal, shoku, four,
# Nearest to years: expectancy, fertility, infant, hiv, mortality, migrant, birth, antioquia,
# Nearest to united: cuba, states, formalized, oddities, appalachia, endomembrane, internship, litoral,
# Nearest to gold: glastonbury, hegemonic, dmz, remarking, metals, grown, kong, conspire,
# Nearest to heavy: parlay, bite, picked, saline, scaring, hmas, gently, preterite,
# Nearest to pressure: silvery, absolutely, melting, sous, undp, humid, schlenkerla, folding,
# Nearest to existence: judge, logia, axioms, commit, manasseh, pesach, prove, defenses,
# Nearest to brother: isl, ibaraki, wife, takla, peshawar, byron, blockaded, decnet,
# Nearest to additional: tld, girondins, wertham, glycogen, legged, inventories, pms, chymotrypsin,
# Nearest to applied: scientists, vesper, meditations, gouda, appreciate, dragster, haploid, downloaded,
# Nearest to dr: toaster, spinrad, smeaton, episode, earl, harmondsworth, goldwater, circulatory,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2573 0.3099 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2380 0.3034 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2235 0.3023 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1293 0.3536 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1919 0.3637 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1571 0.3431 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1919 0.3027 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.2045 0.3050 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2235 0.3293 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1672 0.3106 sec/batch
# Nearest to after: ivana, seaman, imad, was, grew, cornucopia, stripper, stopped,
# Nearest to american: bestseller, jumped, riyadh, emil, wade, flo, simmons, hackett,
# Nearest to these: conquering, arbitrate, therefore, depriving, separations, of, sacramental, aedile,
# Nearest to who: rebellious, quintessentially, did, flavius, her, facemask, acquire, genuine,
# Nearest to the: windsurfing, soichiro, preemptive, an, underlined, fatwas, sig, doubled,
# Nearest to six: one, zero, eight, three, four, wenzel, shoku, five,
# Nearest to years: expectancy, fertility, hiv, infant, mortality, migrant, males, female,
# Nearest to united: cuba, states, oddities, formalized, appalachia, ascertaining, litoral, endomembrane,
# Nearest to gold: glastonbury, metals, dmz, hegemonic, remarking, grown, casas, telegraphic,
# Nearest to heavy: parlay, saline, bite, picked, hmas, tempering, occupied, panzer,
# Nearest to pressure: silvery, absolutely, melting, humid, sous, undp, schlenkerla, folding,
# Nearest to existence: judge, axioms, logia, defenses, commit, coimbra, manasseh, prove,
# Nearest to brother: ibaraki, isl, byron, takla, wife, penalty, decnet, peshawar,
# Nearest to additional: wertham, tld, glycogen, girondins, pms, inventories, chymotrypsin, legged,
# Nearest to applied: scientists, meditations, vesper, gouda, dragster, appreciate, haploid, bream,
# Nearest to dr: toaster, spinrad, episode, smeaton, harmondsworth, earl, goldwater, dougal,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1470 0.3042 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2146 0.3547 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1848 0.3076 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1664 0.2974 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1971 0.3039 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1914 0.2997 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2057 0.3030 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1496 0.3026 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1283 0.3058 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1808 0.3000 sec/batch
# Nearest to after: ivana, imad, cornucopia, was, luzon, francis, seaman, grew,
# Nearest to american: bestseller, jumped, riyadh, emil, flo, max, nicholas, hackett,
# Nearest to these: conquering, arbitrate, separations, therefore, depriving, sacramental, of, aedile,
# Nearest to who: did, flavius, rebellious, facemask, quintessentially, genuine, tat, her,
# Nearest to the: underlined, windsurfing, soichiro, preemptive, ethnographers, an, of, sig,
# Nearest to six: one, zero, eight, three, four, five, wenzel, vernal,
# Nearest to years: expectancy, fertility, infant, hiv, mortality, migrant, female, birth,
# Nearest to united: states, cuba, oddities, appalachia, litoral, ascertaining, formalized, secede,
# Nearest to gold: glastonbury, metals, hegemonic, remarking, dmz, dangerously, vasoconstriction, telegraphic,
# Nearest to heavy: parlay, bite, euphemistic, saline, picked, hmas, occupied, gently,
# Nearest to pressure: silvery, absolutely, melting, sous, humid, undp, schlenkerla, emission,
# Nearest to existence: axioms, logia, judge, pesach, analyses, defenses, prove, there,
# Nearest to brother: ibaraki, peshawar, takla, isl, byron, decnet, penalty, virgil,
# Nearest to additional: wertham, tld, girondins, glycogen, pms, chymotrypsin, fante, inventories,
# Nearest to applied: scientists, meditations, gouda, vesper, appreciate, nordstr, haploid, dragster,
# Nearest to dr: spinrad, toaster, episode, smeaton, circulatory, harmondsworth, dougal, goldwater,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2063 0.3138 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1701 0.3060 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1768 0.3271 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.2048 0.3006 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1677 0.3124 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1538 0.3021 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1699 0.3005 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1064 0.3026 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1776 0.3091 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2049 0.3002 sec/batch
# Nearest to after: was, ivana, luzon, seaman, francis, imad, cornucopia, forced,
# Nearest to american: bestseller, emil, jumped, flo, nine, musician, ron, simmons,
# Nearest to these: conquering, arbitrate, separations, therefore, sacramental, aedile, depriving, hellenistic,
# Nearest to who: did, rebellious, acquire, genuine, samaritans, tat, flavius, her,
# Nearest to the: of, windsurfing, an, alienate, underlined, soichiro, fatwas, record,
# Nearest to six: one, eight, zero, three, five, four, wenzel, seven,
# Nearest to years: expectancy, fertility, infant, mortality, migrant, hiv, birth, female,
# Nearest to united: states, cuba, oddities, litoral, formalized, secede, ascertaining, malleson,
# Nearest to gold: glastonbury, remarking, hegemonic, metals, casas, dmz, esc, grown,
# Nearest to heavy: picked, parlay, saline, bite, euphemistic, ves, hmas, occupied,
# Nearest to pressure: absolutely, silvery, melting, sous, undp, humid, schlenkerla, safeguard,
# Nearest to existence: logia, axioms, defenses, judge, coimbra, manasseh, pesach, prove,
# Nearest to brother: ibaraki, isl, decnet, peshawar, obligation, wife, takla, orb,
# Nearest to additional: tld, fante, inventories, wertham, girondins, chymotrypsin, pms, glycogen,
# Nearest to applied: meditations, scientists, vesper, gouda, appreciate, bream, haploid, programmes,
# Nearest to dr: spinrad, toaster, episode, smeaton, harmondsworth, circulatory, dougal, goldwater,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2266 0.3024 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1077 0.2965 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1542 0.2972 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1413 0.2984 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0180 0.3081 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1440 0.3163 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1439 0.3246 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1380 0.3425 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1836 0.0646 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1261 0.2978 sec/batch
# Nearest to after: was, ivana, luzon, cornucopia, forced, seaman, stripper, imad,
# Nearest to american: bestseller, jumped, emil, hackett, musician, flo, riyadh, beulah,
# Nearest to these: conquering, arbitrate, librarians, separations, aedile, therefore, sacramental, of,
# Nearest to who: acquire, rulership, quintessentially, facemask, rebellious, her, did, tat,
# Nearest to the: of, underlined, an, soichiro, its, record, doubled, windsurfing,
# Nearest to six: zero, one, eight, three, five, four, two, seven,
# Nearest to years: expectancy, fertility, mortality, hiv, migrant, infant, female, birth,
# Nearest to united: states, cuba, litoral, ascertaining, oddities, formalized, grenadines, appalachia,
# Nearest to gold: glastonbury, remarking, hegemonic, metals, casas, fluorspar, kerenyi, conspire,
# Nearest to heavy: euphemistic, parlay, evacuating, picked, bite, tempering, hmas, arrests,
# Nearest to pressure: absolutely, silvery, undp, melting, humid, sous, schlenkerla, safeguard,
# Nearest to existence: axioms, logia, defenses, coimbra, prove, analyses, pesach, manasseh,
# Nearest to brother: ibaraki, isl, obligation, wife, decnet, peshawar, virgil, orb,
# Nearest to additional: tld, fante, inventories, pms, chymotrypsin, wertham, girondins, cyanine,
# Nearest to applied: gouda, scientists, meditations, vesper, appreciate, programmes, granites, nordstr,
# Nearest to dr: spinrad, toaster, episode, circulatory, smeaton, goldwater, blames, dougal,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.1081 0.3164 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0786 0.3049 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0850 0.3208 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0416 0.3041 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.1105 0.3246 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0503 0.2948 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0815 0.3127 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0846 0.3025 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1128 0.3078 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0303 0.3009 sec/batch
# Nearest to after: was, ivana, luzon, imad, forced, stripper, fermanagh, grew,
# Nearest to american: bestseller, jumped, riyadh, musician, flo, hackett, ancestry, simmons,
# Nearest to these: conquering, arbitrate, sacramental, separations, of, therefore, aedile, librarians,
# Nearest to who: acquire, quintessentially, rulership, rebellious, flavius, her, prodigious, vizier,
# Nearest to the: an, of, its, windsurfing, record, turkmenistan, fatwas, preemptive,
# Nearest to six: one, zero, eight, three, four, five, two, wenzel,
# Nearest to years: expectancy, fertility, mortality, hiv, migrant, infant, zero, female,
# Nearest to united: states, cuba, litoral, oddities, ascertaining, appalachia, countries, grenadines,
# Nearest to gold: glastonbury, metals, remarking, hegemonic, fluorspar, casas, kerenyi, grown,
# Nearest to heavy: panzer, hmas, parlay, evacuating, euphemistic, saline, tramway, tempering,
# Nearest to pressure: absolutely, silvery, undp, melting, sous, schlenkerla, humid, reducing,
# Nearest to existence: logia, defenses, axioms, prove, coimbra, judge, analyses, pesach,
# Nearest to brother: ibaraki, decnet, virgil, wife, peshawar, isl, orb, obligation,
# Nearest to additional: fante, tld, inventories, glycogen, pms, cyanine, wertham, chymotrypsin,
# Nearest to applied: scientists, meditations, gouda, programmes, appreciate, bream, nordstr, haploid,
# Nearest to dr: spinrad, toaster, episode, circulatory, blames, smeaton, goldwater, attlee,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0468 0.3127 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0870 0.3157 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0075 0.3041 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0502 0.2966 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0777 0.3165 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0653 0.3132 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0501 0.3100 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.0774 0.2956 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0658 0.3080 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0582 0.2914 sec/batch
# Nearest to after: ivana, luzon, was, stripper, fermanagh, vasquez, cornucopia, truest,
# Nearest to american: bestseller, jumped, musician, riyadh, cockerell, hackett, beulah, wintertime,
# Nearest to these: conquering, separations, of, arbitrate, sacramental, therefore, aedile, librarians,
# Nearest to who: quintessentially, facemask, acquire, prodigious, rulership, did, giraud, flavius,
# Nearest to the: of, an, record, is, its, sig, windsurfing, in,
# Nearest to six: one, zero, eight, three, four, five, two, seven,
# Nearest to years: expectancy, fertility, mortality, migrant, infant, hiv, zero, birth,
# Nearest to united: states, cuba, ascertaining, appalachia, oddities, litoral, secede, countries,
# Nearest to gold: metals, hegemonic, remarking, glastonbury, casas, fluorspar, kerenyi, grown,
# Nearest to heavy: panzer, euphemistic, hmas, evacuating, tempering, parlay, saline, cathodes,
# Nearest to pressure: absolutely, melting, silvery, undp, humid, sous, rotational, schlenkerla,
# Nearest to existence: logia, defenses, axioms, analyses, coimbra, pesach, judge, prove,
# Nearest to brother: ibaraki, virgil, wife, obligation, isl, orb, decnet, peshawar,
# Nearest to additional: fante, inventories, glycogen, tld, pms, cyanine, synchronize, wertham,
# Nearest to applied: meditations, scientists, appreciate, gouda, programmes, granites, haploid, fork,
# Nearest to dr: spinrad, toaster, episode, circulatory, blames, goldwater, attlee, harmondsworth,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0556 0.2996 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0813 0.3073 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0751 0.3140 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0587 0.2981 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0657 0.3099 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0892 0.3019 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0770 0.3024 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0590 0.3065 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0772 0.3029 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0627 0.3059 sec/batch
# Nearest to after: was, ivana, luzon, truest, fermanagh, imad, forced, barton,
# Nearest to american: bestseller, jumped, cockerell, ancestry, wintertime, riyadh, philosophies, playfair,
# Nearest to these: conquering, separations, aedile, arbitrate, sacramental, of, librarians, therefore,
# Nearest to who: did, flavius, acquire, giraud, quintessentially, rulership, usurpers, personal,
# Nearest to the: of, in, its, an, has, by, and, is,
# Nearest to six: one, zero, three, eight, five, four, two, seven,
# Nearest to years: expectancy, fertility, mortality, zero, infant, seven, hiv, migrant,
# Nearest to united: states, cuba, litoral, grenadines, oddities, america, countries, ascertaining,
# Nearest to gold: metals, hegemonic, remarking, fluorspar, glastonbury, casas, grown, uranium,
# Nearest to heavy: euphemistic, panzer, hmas, tempering, ves, garbled, evacuating, cathodes,
# Nearest to pressure: absolutely, melting, silvery, humid, undp, sous, schlenkerla, rotational,
# Nearest to existence: logia, defenses, pesach, axioms, coimbra, prove, judge, planet,
# Nearest to brother: ibaraki, peshawar, wife, obligation, isl, decnet, virgil, grandfather,
# Nearest to additional: fante, inventories, tld, pms, wertham, cyanine, girondins, wu,
# Nearest to applied: meditations, gouda, appreciate, scientists, programmes, granites, bream, nordstr,
# Nearest to dr: spinrad, toaster, episode, circulatory, blames, attlee, survivor, goldwater,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0641 0.3177 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 3.9918 0.2997 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0398 0.2946 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0643 0.3165 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0721 0.3028 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1270 0.3019 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1287 0.3036 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0613 0.2957 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0209 0.3109 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0596 0.2967 sec/batch
# Nearest to after: was, luzon, ivana, truest, imad, cornucopia, fermanagh, seaman,
# Nearest to american: bestseller, jumped, beasley, ancestry, mia, beulah, musician, cockerell,
# Nearest to these: conquering, separations, aedile, librarians, pours, arbitrate, many, koi,
# Nearest to who: facemask, acquire, quintessentially, giraud, flavius, prodigious, did, exiling,
# Nearest to the: of, an, by, has, is, in, record, its,
# Nearest to six: one, zero, eight, three, five, four, two, seven,
# Nearest to years: expectancy, fertility, mortality, birth, zero, infant, seven, migrant,
# Nearest to united: states, cuba, litoral, amendment, america, grenadines, countries, ascertaining,
# Nearest to gold: metals, hegemonic, remarking, glastonbury, casas, fluorspar, esc, telegraphic,
# Nearest to heavy: euphemistic, panzer, hmas, evacuating, tempering, ves, homeostatic, cathodes,
# Nearest to pressure: absolutely, silvery, undp, schlenkerla, humid, melting, templeton, sous,
# Nearest to existence: logia, defenses, coimbra, axioms, prove, pesach, analyses, planet,
# Nearest to brother: ibaraki, decnet, obligation, wife, isl, virgil, grandfather, underscore,
# Nearest to additional: fante, tld, inventories, wu, cyanine, pms, chymotrypsin, wertham,
# Nearest to applied: appreciate, gouda, programmes, scientists, meditations, granites, bream, fork,
# Nearest to dr: spinrad, toaster, circulatory, blames, attlee, episode, goldwater, edmund,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9790 0.3210 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0411 0.2994 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0392 0.3026 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0613 0.3015 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0555 0.3027 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0515 0.2852 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0006 0.3026 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 4.0064 0.3020 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0343 0.3017 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9539 0.2990 sec/batch
# Nearest to after: was, ivana, luzon, imad, fermanagh, cornucopia, truest, barton,
# Nearest to american: bestseller, ancestry, jumped, beasley, baseball, singer, screenwriter, musician,
# Nearest to these: conquering, separations, aedile, of, many, arbitrate, librarians, sacramental,
# Nearest to who: facemask, giraud, acquire, flavius, her, absurdities, quintessentially, personal,
# Nearest to the: of, an, is, by, its, into, record, with,
# Nearest to six: one, zero, eight, three, five, four, two, seven,
# Nearest to years: expectancy, fertility, mortality, migrant, birth, seven, infant, gregorian,
# Nearest to united: states, cuba, litoral, ascertaining, grenadines, america, oddities, countries,
# Nearest to gold: metals, hegemonic, remarking, fluorspar, glastonbury, casas, esc, subtended,
# Nearest to heavy: panzer, hmas, euphemistic, evacuating, ves, homeostatic, porfirio, tempering,
# Nearest to pressure: absolutely, silvery, schlenkerla, melting, undp, templeton, humid, shooters,
# Nearest to existence: logia, prove, defenses, axioms, pesach, coimbra, immaterial, judge,
# Nearest to brother: ibaraki, wife, obligation, decnet, virgil, sons, isl, underscore,
# Nearest to additional: fante, tld, pms, inventories, chymotrypsin, cyanine, synchronize, wu,
# Nearest to applied: gouda, appreciate, scientists, fork, meditations, programmes, commuters, acoustic,
# Nearest to dr: spinrad, toaster, blames, circulatory, attlee, episode, herrera, goldwater,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9614 0.3066 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9307 0.3033 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0404 0.3027 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 3.9997 0.2997 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0426 0.3132 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9926 0.3034 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.8958 0.3053 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9643 0.3120 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9326 0.3062 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9746 0.3006 sec/batch
# Nearest to after: was, ivana, luzon, before, fermanagh, pentameter, stopped, imad,
# Nearest to american: bestseller, jumped, ancestry, makeup, latino, islander, leagues, philosophies,
# Nearest to these: conquering, of, separations, aedile, many, sacramental, arbitrate, librarians,
# Nearest to who: facemask, acquire, flavius, giraud, quintessentially, reception, overcrowding, rulership,
# Nearest to the: of, has, is, an, in, its, record, by,
# Nearest to six: one, zero, eight, three, five, four, two, seven,
# Nearest to years: expectancy, fertility, zero, seven, mortality, migrant, deaths, female,
# Nearest to united: states, cuba, ascertaining, america, countries, oddities, amendment, litoral,
# Nearest to gold: metals, hegemonic, fluorspar, glastonbury, remarking, casas, silver, woodworking,
# Nearest to heavy: panzer, hmas, euphemistic, porfirio, evacuating, homeostatic, ves, tempering,
# Nearest to pressure: absolutely, silvery, melting, schlenkerla, undp, templeton, humid, sous,
# Nearest to existence: logia, prove, defenses, axioms, coimbra, predictions, pesach, judge,
# Nearest to brother: ibaraki, decnet, wife, obligation, virgil, underscore, infante, telephoned,
# Nearest to additional: fante, tld, pms, inventories, cyanine, glycogen, chymotrypsin, transcribe,
# Nearest to applied: appreciate, gouda, fork, commuters, scientists, programmes, proficiency, acoustic,
# Nearest to dr: spinrad, toaster, circulatory, episode, blames, attlee, undergo, herrera,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9755 0.3077 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9914 0.3033 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9460 0.3048 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0071 0.3013 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0200 0.2996 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9705 0.2992 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9834 0.3031 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9671 0.2993 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 4.0066 0.2997 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0218 0.2989 sec/batch
# Nearest to after: was, ivana, luzon, pentameter, fermanagh, vasquez, before, truest,
# Nearest to american: bestseller, makeup, ancestry, beasley, baseball, jumped, latino, screenwriter,
# Nearest to these: conquering, separations, many, aedile, of, arbitrate, librarians, sacramental,
# Nearest to who: facemask, giraud, reception, personal, acquire, absurdities, erasure, corrupt,
# Nearest to the: of, is, has, an, in, by, its, with,
# Nearest to six: one, zero, eight, five, three, four, two, seven,
# Nearest to years: expectancy, fertility, mortality, zero, seven, deaths, age, migrant,
# Nearest to united: states, cuba, countries, oddities, ascertaining, amendment, america, grenadines,
# Nearest to gold: metals, hegemonic, remarking, fluorspar, glastonbury, silver, bronze, casas,
# Nearest to heavy: panzer, hmas, ves, porfirio, evacuating, tempering, homeostatic, warplanes,
# Nearest to pressure: absolutely, melting, templeton, silvery, schlenkerla, humid, undp, isotropic,
# Nearest to existence: logia, defenses, prove, axioms, pesach, coimbra, schwarz, predictions,
# Nearest to brother: ibaraki, obligation, wife, virgil, decnet, infante, peshawar, grandfather,
# Nearest to additional: fante, tld, cyanine, inventories, pms, glycogen, transcribe, chymotrypsin,
# Nearest to applied: appreciate, gouda, meditations, fork, scientists, proficiency, acoustic, programmes,
# Nearest to dr: spinrad, episode, toaster, blames, attlee, circulatory, undergo, syringe,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9967 0.3068 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9893 0.3002 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9846 0.2977 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0031 0.2984 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0545 0.3019 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0185 0.2994 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9765 0.3032 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9861 0.3008 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9557 0.3025 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0267 0.3056 sec/batch
# Nearest to after: was, luzon, fermanagh, ivana, the, period, before, pentameter,
# Nearest to american: beasley, bestseller, ancestry, mel, baseball, makeup, screenwriter, jumped,
# Nearest to these: conquering, separations, of, many, aedile, pours, therefore, koi,
# Nearest to who: acquire, personal, exiling, former, facemask, corrupt, usurpers, giraud,
# Nearest to the: of, is, has, and, by, in, an, with,
# Nearest to six: one, zero, eight, five, three, four, two, seven,
# Nearest to years: expectancy, fertility, mortality, zero, seven, age, birth, deaths,
# Nearest to united: states, cuba, countries, amendment, of, america, litoral, grenadines,
# Nearest to gold: metals, hegemonic, fluorspar, remarking, glastonbury, silver, bronze, grown,
# Nearest to heavy: panzer, euphemistic, ves, porfirio, homeostatic, hmas, evacuating, garbled,
# Nearest to pressure: absolutely, templeton, schlenkerla, humid, melting, isotropic, silvery, undp,
# Nearest to existence: defenses, logia, prove, amphibious, schwarz, axioms, coimbra, fomented,
# Nearest to brother: ibaraki, wife, obligation, virgil, decnet, underscore, grandfather, sons,
# Nearest to additional: fante, transcribe, inventories, tld, pms, wu, meetings, synchronize,
# Nearest to applied: appreciate, gouda, scientists, meditations, fork, programmes, acoustic, granites,
# Nearest to dr: spinrad, undergo, episode, blames, attlee, toaster, circulatory, foreign,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.9622 0.3089 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 4.0846 0.2977 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 4.0494 0.3028 sec/batch
# ...
# Nearest to these: of, many, remaining, their, such, only, conquering, separately,
# Nearest to who: known, associate, to, former, preinstalled, riichi, facemask, acquire,
# Nearest to the: of, in, and, a, by, is, with, an,
# Nearest to six: one, five, three, four, zero, eight, two, seven,
# Nearest to years: expectancy, seven, zero, mortality, age, fertility, female, life,
# Nearest to united: states, countries, cuba, oddities, is, of, ascertaining, america,
# Nearest to gold: medal, silver, bronze, hegemonic, uranium, metals, fluorspar, glastonbury,
# Nearest to heavy: panzer, leather, porfirio, gnp, yerkes, euphemistic, miao, led,
# Nearest to pressure: absolutely, templeton, humid, rotational, violently, schlenkerla, vents, balance,
# Nearest to existence: prove, sulfide, defenses, agnosticism, ventures, edwin, remains, disaster,
# Nearest to brother: grandfather, decnet, virgil, quitting, daughter, mcfowl, ibaraki, wife,
# Nearest to additional: transcribe, fante, decisions, glycogen, synchronize, nirenberg, meetings, mrna,
# Nearest to applied: fork, appreciate, commuters, apotheosis, sciences, proficiency, acoustic, mascheroni,
# Nearest to dr: rioting, worded, alarmed, tli, bujold, mic, attlee, spinrad,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8050 0.3082 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8673 0.3017 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8298 0.3026 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8579 0.2988 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8554 0.2998 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8871 0.2957 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8475 0.3126 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8512 0.3004 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8496 0.3032 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8648 0.2962 sec/batch
# Nearest to after: was, the, with, before, nagy, during, period, which,
# Nearest to american: latino, ancestry, makeup, baseball, actors, beasley, america, mel,
# Nearest to these: of, many, their, remaining, conquering, dealing, only, such,
# Nearest to who: former, associate, known, preinstalled, governed, hamish, to, lalo,
# Nearest to the: of, in, by, and, a, is, an, with,
# Nearest to six: one, five, three, zero, eight, four, two, seven,
# Nearest to years: seven, expectancy, zero, mortality, fertility, five, female, age,
# Nearest to united: states, countries, cuba, of, is, oddities, america, u,
# Nearest to gold: hegemonic, medal, silver, uranium, fluorspar, metals, bronze, minted,
# Nearest to heavy: panzer, gnp, porfirio, leather, euphemistic, yerkes, garbled, miao,
# Nearest to pressure: absolutely, templeton, humid, rotational, violently, ranatunga, balance, determinant,
# Nearest to existence: prove, agnosticism, sulfide, edwin, ventures, remains, oldest, defenses,
# Nearest to brother: grandfather, virgil, decnet, mcfowl, daughter, ibaraki, quitting, danorum,
# Nearest to additional: transcribe, decisions, fante, meetings, synchronize, consummation, glycogen, nirenberg,
# Nearest to applied: appreciate, fork, sciences, apotheosis, commuters, mascheroni, proficiency, orcinus,
# Nearest to dr: rioting, worded, alarmed, tli, bujold, attlee, spinrad, mic,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8439 0.3045 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8430 0.3006 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8320 0.3040 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8373 0.3017 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.9239 0.3185 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8415 0.3109 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9718 0.3254 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8482 0.3125 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9099 0.3331 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.7921 0.3067 sec/batch
# Nearest to after: was, the, during, with, before, soon, nagy, which,
# Nearest to american: latino, baseball, ancestry, makeup, mel, beasley, actors, d,
# Nearest to these: of, many, their, such, remaining, some, depositary, dealing,
# Nearest to who: former, associate, known, lalo, hamish, dade, kullervo, leaving,
# Nearest to the: of, by, in, and, a, an, as, with,
# Nearest to six: one, five, three, zero, eight, four, two, seven,
# Nearest to years: expectancy, seven, zero, female, five, two, mortality, fertility,
# Nearest to united: states, cuba, countries, of, amendment, is, oddities, u,
# Nearest to gold: medal, hegemonic, silver, bronze, uranium, metals, fluorspar, remarking,
# Nearest to heavy: panzer, leather, gnp, porfirio, led, yerkes, bayou, miao,
# Nearest to pressure: absolutely, templeton, humid, rotational, ranatunga, violently, reincorporated, schlenkerla,
# Nearest to existence: prove, sulfide, agnosticism, defenses, ventures, oldest, edwin, remains,
# Nearest to brother: grandfather, mcfowl, decnet, virgil, caroline, ibaraki, quitting, nephews,
# Nearest to additional: fante, transcribe, decisions, synchronize, meetings, glycogen, brin, nirenberg,
# Nearest to applied: fork, appreciate, apotheosis, commuters, proficiency, sciences, mascheroni, orcinus,
# Nearest to dr: rioting, worded, alarmed, attlee, tli, bujold, spinrad, modifications,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7807 0.3334 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8564 0.3154 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7948 0.3228 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8504 0.3243 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8343 0.3159 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8542 0.3185 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8498 0.2000 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8446 0.3079 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8405 0.3077 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8611 0.3115 sec/batch
# Nearest to after: was, the, with, which, before, soon, during, believed,
# Nearest to american: d, baseball, ancestry, mel, latino, makeup, inventor, beasley,
# Nearest to these: of, many, their, remaining, some, such, were, dealing,
# Nearest to who: known, associate, to, former, leaving, kullervo, lalo, preinstalled,
# Nearest to the: of, by, in, and, a, with, an, which,
# Nearest to six: one, five, three, eight, zero, four, two, seven,
# Nearest to years: expectancy, seven, zero, mortality, female, life, fertility, five,
# Nearest to united: states, cuba, is, of, s, countries, america, oddities,
# Nearest to gold: medal, hegemonic, silver, bronze, uranium, fluorspar, remarking, financial,
# Nearest to heavy: panzer, leather, porfirio, gnp, led, yerkes, differences, euphemistic,
# Nearest to pressure: absolutely, templeton, ranatunga, humid, rotational, violently, determinant, cherokees,
# Nearest to existence: prove, agnosticism, sulfide, ventures, remains, defenses, edwin, commit,
# Nearest to brother: grandfather, daughter, decnet, wife, mcfowl, ibaraki, virgil, sons,
# Nearest to additional: fante, transcribe, decisions, synchronize, meetings, brin, glycogen, hole,
# Nearest to applied: fork, appreciate, apotheosis, commuters, proficiency, mascheroni, orcinus, sciences,
# Nearest to dr: rioting, worded, alarmed, trypanosomiasis, mic, spinrad, tli, emergency,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8218 0.3690 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8275 0.3586 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.7848 0.3226 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8218 0.3317 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8364 0.3154 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8153 0.3528 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8942 0.3226 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7337 0.3258 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8191 0.3143 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7869 0.3436 sec/batch
# Nearest to after: was, with, before, the, which, soon, during, nagy,
# Nearest to american: latino, ancestry, makeup, leagues, america, baseball, mel, actors,
# Nearest to these: of, many, are, some, their, such, remaining, and,
# Nearest to who: associate, former, hamish, leaving, known, preinstalled, kullervo, riichi,
# Nearest to the: of, in, a, by, and, is, as, an,
# Nearest to six: one, five, three, zero, four, eight, two, seven,
# Nearest to years: seven, expectancy, zero, female, four, mortality, two, five,
# Nearest to united: states, cuba, oddities, america, countries, u, is, comparable,
# Nearest to gold: medal, silver, hegemonic, uranium, bronze, financial, fluorspar, metals,
# Nearest to heavy: panzer, leather, gnp, led, porfirio, confederates, euphemistic, miao,
# Nearest to pressure: absolutely, templeton, humid, violently, determinant, ranatunga, rotational, cherokees,
# Nearest to existence: agnosticism, prove, ventures, sulfide, defenses, remains, edwin, commit,
# Nearest to brother: grandfather, decnet, virgil, caroline, quitting, danorum, ibaraki, mcfowl,
# Nearest to additional: transcribe, fante, decisions, synchronize, glycogen, arno, meetings, nirenberg,
# Nearest to applied: fork, appreciate, sciences, apotheosis, commuters, proficiency, compuserve, mascheroni,
# Nearest to dr: rioting, alarmed, worded, trypanosomiasis, mic, emergency, markers, tli,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7777 0.3297 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8342 0.3702 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8566 0.3079 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8500 0.3041 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8019 0.3158 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.9036 0.3496 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8423 0.3206 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8234 0.3222 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8250 0.3794 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8416 0.3787 sec/batch
# Nearest to after: was, with, before, the, during, soon, shortly, nagy,
# Nearest to american: latino, ancestry, makeup, baseball, mel, leagues, america, ancestries,
# Nearest to these: of, many, their, remaining, are, only, some, and,
# Nearest to who: by, hamish, to, husbands, former, associate, sent, smarter,
# Nearest to the: of, in, and, by, a, is, as, an,
# Nearest to six: one, five, three, zero, eight, four, two, seven,
# Nearest to years: expectancy, seven, zero, female, mortality, four, five, two,
# Nearest to united: states, cuba, america, countries, oddities, of, fayette, amendment,
# Nearest to gold: medal, silver, hegemonic, bronze, uranium, financial, metals, krugerrand,
# Nearest to heavy: panzer, leather, gnp, porfirio, led, yerkes, differences, euphemistic,
# Nearest to pressure: absolutely, humid, templeton, rotational, ranatunga, determinant, violently, reincorporated,
# Nearest to existence: agnosticism, prove, ventures, remains, oldest, defenses, sulfide, forteana,
# Nearest to brother: grandfather, decnet, ibaraki, caroline, mcfowl, quitting, younger, studying,
# Nearest to additional: transcribe, fante, decisions, synchronize, arno, nirenberg, meetings, brin,
# Nearest to applied: fork, appreciate, proficiency, apotheosis, sciences, commuters, mascheroni, compuserve,
# Nearest to dr: rioting, worded, alarmed, rap, mic, bujold, trypanosomiasis, tli,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8509 0.3287 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8572 0.3603 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8541 0.3319 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8257 0.3047 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8756 0.3004 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8455 0.3151 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8335 0.3067 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8098 0.2954 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8304 0.3054 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8113 0.3077 sec/batch
# Nearest to after: was, the, before, with, during, soon, period, shortly,
# Nearest to american: ancestry, latino, makeup, baseball, america, leagues, actors, songwriters,
# Nearest to these: of, are, many, their, such, remaining, only, some,
# Nearest to who: to, former, by, associate, sent, known, leaving, hamish,
# Nearest to the: of, and, in, by, a, as, is, which,
# Nearest to six: one, five, three, eight, zero, four, two, seven,
# Nearest to years: seven, expectancy, zero, five, female, mortality, two, four,
# Nearest to united: states, countries, of, cuba, u, nations, amendment, america,
# Nearest to gold: silver, medal, hegemonic, bronze, uranium, fluorspar, metals, krugerrand,
# Nearest to heavy: leather, panzer, porfirio, gnp, led, euphemistic, ves, differences,
# Nearest to pressure: absolutely, templeton, humid, ranatunga, violently, determinant, rotational, shooters,
# Nearest to existence: remains, agnosticism, prove, oldest, ventures, defenses, sulfide, forteana,
# Nearest to brother: grandfather, decnet, daughter, mcfowl, caroline, ibaraki, younger, quitting,
# Nearest to additional: transcribe, fante, decisions, synchronize, meetings, brin, glycogen, consummation,
# Nearest to applied: appreciate, apotheosis, fork, sciences, commuters, proficiency, establishing, compuserve,
# Nearest to dr: rioting, alarmed, worded, tli, attlee, mic, bujold, modifications,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8559 0.3156 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8129 0.3044 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9412 0.2949 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9040 0.3549 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8795 0.3598 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8117 0.3679 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7745 0.4057 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8569 0.3593 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7607 0.3477 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8856 0.3504 sec/batch
# Nearest to after: was, the, with, before, during, from, nagy, shortly,
# Nearest to american: d, baseball, makeup, deaths, ancestry, dermot, mel, latino,
# Nearest to these: many, of, are, some, only, dealing, such, and,
# Nearest to who: associate, former, dade, hamish, smarter, testimonials, rhythmically, lalo,
# Nearest to the: of, by, in, and, a, is, as, which,
# Nearest to six: one, five, three, eight, four, zero, two, seven,
# Nearest to years: zero, expectancy, female, seven, mortality, two, five, life,
# Nearest to united: states, cuba, u, of, countries, us, amendment, is,
# Nearest to gold: silver, medal, hegemonic, bronze, uranium, financial, fluorspar, awarded,
# Nearest to heavy: leather, porfirio, panzer, led, gnp, differences, ves, euphemistic,
# Nearest to pressure: absolutely, templeton, ranatunga, humid, violently, reincorporated, rotational, determinant,
# Nearest to existence: prove, remains, agnosticism, oldest, ventures, defenses, sulfide, forteana,
# Nearest to brother: grandfather, decnet, caroline, mcfowl, younger, studying, quitting, ibaraki,
# Nearest to additional: transcribe, fante, decisions, synchronize, brin, meetings, glycogen, arno,
# Nearest to applied: fork, apotheosis, appreciate, commuters, sciences, proficiency, establishing, compuserve,
# Nearest to dr: rioting, worded, alarmed, trypanosomiasis, tli, modifications, attlee, mic,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8376 0.3598 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.7941 0.3549 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
